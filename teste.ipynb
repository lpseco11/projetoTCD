# %%
import numpy as np
import os

path = "FacialTracking_Actors_01-24"

facial_list = os.listdir(path)
#print(facial_list)
f_list=facial_list.copy()
emotions= ["01","02","03","04","05","06","07","08"]
f_list_neutral_01=[]
f_list_neutral_02=[]
f_list_neutral_03=[]
f_list_neutral_04=[]
f_list_neutral_05=[]
f_list_neutral_06=[]
f_list_neutral_07=[]
f_list_neutral_08=[]
f_list_neutral_09=[]
f_list_neutral_010=[]
f_list_neutral_011=[]
f_list_neutral_012=[]
f_list_neutral_013=[]
f_list_neutral_014=[]
f_list_neutral_015=[]
f_list_neutral_016=[]
f_list_neutral_017=[]
f_list_neutral_018=[]
f_list_neutral_019=[]
f_list_neutral_020=[]
f_list_neutral_021=[]
f_list_neutral_022=[]
f_list_neutral_023=[]
f_list_neutral_024=[]

#iremos considerar que existe um formato "nn-nn-00-nn-nn-nn-nn.csv"
#f_list_neutral = [elemento for elemento in f_list if elemento.split('-')[2] == "01"]
#print(f_list_neutral)
for i in range(len(emotions)):
    f_list_neutral_01 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="01.csv")]
    f_list_neutral_02 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="02.csv")]
    f_list_neutral_03 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="03.csv")]
    f_list_neutral_04 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="04.csv")]
    f_list_neutral_05 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="05.csv")]
    f_list_neutral_06 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="06.csv")]
    f_list_neutral_07 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="07.csv")]
    f_list_neutral_08 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="08.csv")]
    f_list_neutral_09 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="09.csv")]
    f_list_neutral_010 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="10.csv")]
    f_list_neutral_011 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="11.csv")]
    f_list_neutral_012 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="12.csv")]
    f_list_neutral_013 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="13.csv")]
    f_list_neutral_014 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="14.csv")]
    f_list_neutral_015 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="15.csv")]
    f_list_neutral_016 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="16.csv")]
    f_list_neutral_017 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="17.csv")]
    f_list_neutral_018 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="18.csv")]
    f_list_neutral_019 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="19.csv")]
    f_list_neutral_020 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="20.csv")]
    f_list_neutral_021 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="21.csv")]
    f_list_neutral_022 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="22.csv")]
    f_list_neutral_023 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="23.csv")]
    f_list_neutral_024 += [elemento for elemento in f_list if (elemento.split('-')[2] ==emotions[i]  and elemento.split('-')[6]=="24.csv")]
    
print(f_list_neutral_021)
